# %%
import os
import json
import datetime
import warnings
import requests

from LocalUtilities.WriteToInflux import vehicles, createInfluxEntry, getInfluxPayload,writeToInflux
warnings.filterwarnings('ignore')

# %load_ext autoreload
# %autoreload 2

rootPath = r"C:\Users\ortun\OneDrive\PURDUE\CLASSES\ECE695\PROJECT\CODE\DATA"
MEASUREMENT = 'telemetry'
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
j = 0

ID = vehicles[j]['id']
make = vehicles[j]['make']
model = vehicles[j]['model']
year = vehicles[j]['year']

header = '{},id={},make={},model={},year={} '.format(MEASUREMENT, ID, make, model, year)

path = "{}\{} {} {}".format(rootPath, make, model, year)
files = os.listdir(path)

for i in range(len(files)):
    with open(path + '\{}'.format(files[i]), 'r') as myFile:
        dataList = myFile.read().split('\n')
        influxPayload = getInfluxPayload(ID, make, model, year, dataList)
        try:
            writeToInflux(influxPayload)
        except:
            pass
# Out:
# Expecting value: line 1 column 1 (char 0)
# Expecting value: line 1 column 1 (char 0)
# Succesfully written records to Influx!
# Succesfully written records to Influx!
# Succesfully written records to Influx!
# Succesfully written records to Influx!
# Expecting ':' delimiter: line 1 column 840 (char 839)
# Succesfully written records to Influx!
# Succesfully written records to Influx!
# Invalid control character at: line 1 column 663 (char 662)
# Succesfully written records to Influx!
# Succesfully written records to Influx!
# Succesfully written records to Influx!
# Succesfully written records to Influx!
# Succesfully written records to Influx!
# Succesfully written records to Influx!
# Succesfully written records to Influx!

# %%
influxPayload
# Out:
# 'telemetry,id=1,make=toyota,model=rav4,year=2022 RPM=2177.25,Speed=110.0,EngineLoad=79.2156862745098,CoolantTemp=87.0,IntakeTemp=7.0,FuelLevel=31.764705882352942,AmbientTemp=7.0,EngineOilTemp=84.0,AirFlowRate=28.89,ThrottlePosition=33.333333333333336,AbsoluteLoad=52.94117647058823,Ax=-0.08349609375,Ay=0.09228515625,Az=0.95751953125,Gx=-0.48091603053435117,Gy=-1.8702290076335877,Gz=-0.42748091603053434 1677305231\ntelemetry,id=1,make=toyota,model=rav4,year=2022 RPM=2192.75,Speed=112.0,EngineLoad=68.62745098039215,CoolantTemp=87.0,IntakeTemp=7.0,FuelLevel=34.11764705882353,AmbientTemp=7.0,EngineOilTemp=84.0,AirFlowRate=4.59,ThrottlePosition=16.862745098039216,AbsoluteLoad=29.41176470588235,Ax=-0.090576171875,Ay=0.020263671875,Az=1.253662109375,Gx=-0.6641221374045801,Gy=0.648854961832061,Gz=-0.26717557251908397 1677305232\ntelemetry,id=1,make=toyota,model=rav4,year=2022 RPM=2162.5,Speed=111.0,EngineLoad=24.313725490196077,CoolantTemp=87.0,IntakeTemp=7.0,FuelLevel=37.64705882352941,AmbientTemp=7.0,EngineOilTemp=84.0,AirFlowRate=10.6,ThrottlePosition=20.0,AbsoluteLoad=18.03921568627451,Ax=0.018798828125,Ay=-0.07861328125,Az=1.18994140625,Gx=-0.19083969465648856,Gy=0.5190839694656488,Gz=-0.37404580152671757 1677305234\ntelemetry,id=1,make=toyota,model=rav4,year=2022 RPM=2137.5,Speed=111.0,EngineLoad=24.313725490196077,CoolantTemp=87.0,IntakeTemp=8.0,FuelLevel=34.509803921568626,AmbientTemp=8.0,EngineOilTemp=84.0,AirFlowRate=8.46,ThrottlePosition=19.215686274509803,AbsoluteLoad=17.254901960784313,Ax=0.0322265625,Ay=-0.05224609375,Az=1.031494140625,Gx=-0.45038167938931295,Gy=0.5954198473282443,Gz=-0.3969465648854962 1677305235\ntelemetry,id=1,make=toyota,model=rav4,year=2022 RPM=2136.5,Speed=109.0,EngineLoad=29.41176470588235,CoolantTemp=88.0,IntakeTemp=8.0,FuelLevel=37.64705882352941,AmbientTemp=8.0,EngineOilTemp=84.0,AirFlowRate=19.46,ThrottlePosition=21.96078431372549,AbsoluteLoad=25.098039215686274,Ax=-0.045166015625,Ay=-0.10546875,Az=1.12353515625,Gx=0.09923664122137404,Gy=0.3282442748091603,Gz=-0.33587786259541985 1677305236\ntelemetry,id=1,make=toyota,model=rav4,year=2022 RPM=1773.25,Speed=110.0,EngineLoad=66.66666666666667,CoolantTemp=87.0,IntakeTemp=8.0,FuelLevel=37.64705882352941,AmbientTemp=8.0,EngineOilTemp=84.0,AirFlowRate=5.92,ThrottlePosition=16.470588235294116,AbsoluteLoad=39.21568627450981,Ax=-0.097412109375,Ay=-0.071044921875,Az=1.256591796875,Gx=0.31297709923664124,Gy=0.48854961832061067,Gz=-0.24427480916030533 1677305237\ntelemetry,id=1,make=toyota,model=rav4,year=2022 RPM=1716.25,Speed=108.0,EngineLoad=14.117647058823529,CoolantTemp=88.0,IntakeTemp=8.0,FuelLevel=34.509803921568626,AmbientTemp=8.0,EngineOilTemp=84.0,AirFlowRate=4.03,ThrottlePosition=16.862745098039216,AbsoluteLoad=9.803921568627452,Ax=0.025634765625,Ay=-0.11669921875,Az=1.28857421875,Gx=-0.22900763358778625,Gy=0.8244274809160306,Gz=-0.16793893129770993 1677305238\ntelemetry,id=1,make=toyota,model=rav4,year=2022 RPM=1660.75,Speed=105.0,EngineLoad=16.07843137254902,CoolantTemp=88.0,IntakeTemp=8.0,FuelLevel=38.8235294117647,AmbientTemp=8.0,EngineOilTemp=84.0,AirFlowRate=4.7,ThrottlePosition=17.254901960784313,AbsoluteLoad=11.372549019607844,Ax=-0.159423828125,Ay=-0.1259765625,Az=0.90966796875,Gx=1.4732824427480915,Gy=0.9465648854961832,Gz=0.20610687022900764 1677305240\ntelemetry,id=1,make=toyota,model=rav4,year=2022 RPM=1609.25,Speed=104.0,EngineLoad=16.07843137254902,CoolantTemp=87.0,IntakeTemp=8.0,FuelLevel=40.3921568627451,AmbientTemp=8.0,EngineOilTemp=84.0,AirFlowRate=4.43,ThrottlePosition=17.254901960784313,AbsoluteLoad=11.372549019607844,Ax=-0.056884765625,Ay=-0.04541015625,Az=0.731201171875,Gx=0.015267175572519083,Gy=0.5190839694656488,Gz=-0.17557251908396945 1677305241\ntelemetry,id=1,make=toyota,model=rav4,year=2022 RPM=1591.25,Speed=100.0,EngineLoad=27.058823529411764,CoolantTemp=87.0,IntakeTemp=8.0,FuelLevel=34.90196078431372,AmbientTemp=8.0,EngineOilTemp=84.0,AirFlowRate=3.65,ThrottlePosition=16.470588235294116,AbsoluteLoad=17.64705882352 ...
